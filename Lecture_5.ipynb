# %% [markdown]
# <a href="https://colab.research.google.com/github/inphinatea/CS104/blob/main/Lecture_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str = "Hello World"

print(str[0], str[1],str[3])

print(str[-1], str[-2], str[-3])

print(str[:3]); print(str[5:7]); str[3:-3]

yn = str.find('H')

print(yn)

names = ["connor", "ur mom", "big poppa"]

placement = names.append("ur mom")

print(placement)

for name in names:
    print(name)

for index in range(len(names)):
    print(index)
# Out:
# H e l
# d l r
# Hel
#  W
# 0
# None
# connor
# ur mom
# big poppa
# ur mom
# 0
# 1
# 2
# 3

# %%
with open("helloworld.txt", "r") as f:
  lines = f.readlines()

print(lines)

for line in lines:
  print(line)
  print(line.strip())
# Out:
# ['Hello World!']
# Hello World!
# Hello World!

# %%
with open("helloworld.txt", "w") as f:
  f.write("Hello World!") #print("Hello World!", file = f:
print("File helloworld.txt is made")
# Out:
#   File "/tmp/ipykernel_3754/3295419468.py", line 2
#     f.write("Hello World!" \n) #print("Hello World!", file = f)
#                             ^
# SyntaxError: unexpected character after line continuation character

# %%
for i in range(len(names)):
  print(names[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3754/3033807300.py in <cell line: 0>()
#       1 for i in range(len(names)):
# ----> 2   print(names(i))
#
# TypeError: 'list' object is not callable
