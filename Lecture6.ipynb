# %% [markdown]
# <a href="https://colab.research.google.com/github/inphinatea/CS104/blob/main/Lecture6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
start = 0
stop = 20
step = 1


x = int(input("Enter an Integer Here: "))

angle = 30
b = math.sin(angle * math.pi / 180)
print(b)
# Out:
# Enter an Integer Here: 5
# 0.49999999999999994

# %%
import matplotlib.pyplot as plt
import math
x = []
y = []
z = []

for a in range(0,360,10):
  x.append(a)
  y.append(math.sin(a * math.pi / 180))
  z.append(math.cos(a * math.pi / 180))
plt.plot(x,y, color = "red")
plt.plot(x,z)

# %%
sys.argv[0]
sys.argv[1:]
sys.exit

# %%
dec_msg = ""

for ch in enc_msg:
  dec_msg += chr(ord(ch) - cipher)
print(dec_msg)
